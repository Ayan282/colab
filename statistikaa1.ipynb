# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayan282/colab/blob/main/statistikaa1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-493e798b-fed1-44d7-85bd-9f700d9ce18c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-493e798b-fed1-44d7-85bd-9f700d9ce18c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel("Data (2).xlsx")

# %%
df
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 0            1    Male   20         IT        Bachelor      Baku     175
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 2            3    Male   21         IT        Bachelor      Baku     180
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 4            5    Male   24    Finance          Master      Baku     172
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 6            7    Male   22  Marketing        Bachelor      Baku     178
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 8            9    Male   23         IT          Master      Baku     185
# 9           10  Female   24  Marketing          Master     Ganja     170
# 10          11    Male   22    Finance        Bachelor      Baku     176
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# ...

# %%
df.groupby("Department").agg({'Age':['mean','median']})
# Out:
#                   Age
#                  mean median
# Department
# Finance     23.000000   23.0
# IT          20.857143   21.0
# Marketing   23.166667   23.0

# %%
df.groupby("Department").agg({'Exam_Score':['min','max']})
# Out:
#            Exam_Score
#                   min max
# Department
# Finance            73  97
# IT                 69  93
# Marketing          65  95

# %%
df["range"]=df["Salary"].max()-df["Salary"].min()
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 0            1    Male   20         IT        Bachelor      Baku     175
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 2            3    Male   21         IT        Bachelor      Baku     180
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 4            5    Male   24    Finance          Master      Baku     172
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 6            7    Male   22  Marketing        Bachelor      Baku     178
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 8            9    Male   23         IT          Master      Baku     185
# 9           10  Female   24  Marketing          Master     Ganja     170
# 10          11    Male   22    Finance        Bachelor      Baku     176
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# ...

# %% [markdown]
# salary sutunundaki max ve min deyerler ferqi 1000 olduguna gore range=1000

# %%
df[['Weight','Height']].cov()
# Out:
#             Weight     Height
# Weight  133.397368  86.152632
# Height   86.152632  58.431579

# %% [markdown]
# eger + olarsa eyni istiqametli hereket edir weight artdiqda height de artir

# %%
df[['Weight','Height']].corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.975823
# Height  0.975823  1.000000

# %%
df['Q1']=df['Exam_Score'].quantile(0.25)
df['Q2']=df['Exam_Score'].quantile(0.50)
df['Q3']=df['Exam_Score'].quantile(0.75)

# %%
df['Q1']=df['Salary'].quantile(0.25)
df['Q2']=df['Salary'].quantile(0.50)
df['Q3']=df['Salary'].quantile(0.75)
IQR=df['Q3']-df['Q1']

# %%
df['Exam_Score'].std()
# Out:
# 9.441649053110652

# %%
df[['Weight','Height']].cov()
# Out:
#             Weight     Height
# Weight  133.397368  86.152632
# Height   86.152632  58.431579

# %%
df[['Weight','Height']].corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.975823
# Height  0.975823  1.000000

# %%
df.groupby("Department")["Exam_Score"].mean()
# Out:
# Department
# Finance      84.571429
# IT           84.571429
# Marketing    78.500000
# Name: Exam_Score, dtype: float64

# %% [markdown]
# Finance,IT deparmentde exam scorun orta qiymeti eynidir amma Marketing nisbeten azdir

# %%
df["Sales"].std()
# Out:
# 883.5149598113924

# %%
df["Salary"].std()
# Out:
# 261.8637653035398

# %%
df["Sales"].var()
# Out:
# 780598.6842105263

# %%
df["Salary"].var()
# Out:
# 68572.63157894737

# %% [markdown]
# Sales daha deyiskendir

# %%
df['Q1']=df['Height'].quantile(0.25)
df['Q2']=df['Height'].quantile(0.50)
df['Q3']=df['Height'].quantile(0.75)
IQR=df['Q3']-df['Q1']
min_outlier=df["Q1"]-1.5*IQR
max_outlier=df["Q3"]+ 1.5*IQR

# %%
min_outlier
# Out:
# 0     148.5
# 1     148.5
# 2     148.5
# 3     148.5
# 4     148.5
# 5     148.5
# 6     148.5
# 7     148.5
# 8     148.5
# 9     148.5
# 10    148.5
# 11    148.5
# 12    148.5
# 13    148.5
# 14    148.5
# 15    148.5
# 16    148.5
# 17    148.5
# 18    148.5
# 19    148.5
# dtype: float64

# %%
max_outlier
# Out:
# 0     194.5
# 1     194.5
# 2     194.5
# 3     194.5
# 4     194.5
# 5     194.5
# 6     194.5
# 7     194.5
# 8     194.5
# 9     194.5
# 10    194.5
# 11    194.5
# 12    194.5
# 13    194.5
# 14    194.5
# 15    194.5
# 16    194.5
# 17    194.5
# 18    194.5
# 19    194.5
# dtype: float64

# %%
df[['Age','Salary']].corr()
# Out:
#              Age    Salary
# Age     1.000000  0.716001
# Salary  0.716001  1.000000

# %%
Age ve Salary sutunu arasindaki elaqe gucludur

# %%
df[['Age','Salary']].cov()
# Out:
#                Age        Salary
# Age       2.536842    298.631579
# Salary  298.631579  68572.631579

# %% [markdown]
# yas artdiqca maas artir

# %%
df[['Exam_Score','Salary']].corr()
# Out:
#             Exam_Score    Salary
# Exam_Score    1.000000  0.756555
# Salary        0.756555  1.000000

# %% [markdown]
# bu elaqe cox menali olmaya biler cunki exam score maasa bir basa tesir eden amil deyil

# %%
df[['Height','Weight']].corr()
# Out:
#           Height    Weight
# Height  1.000000  0.975823
# Weight  0.975823  1.000000

# %% [markdown]
# en mentiqli elaqe ceki ve uzunluq arasindadir burada elaqe daha gucludur

# %%
df[['Exam_Score','Salary']].corr()
# Out:
#             Exam_Score    Salary
# Exam_Score    1.000000  0.756555
# Salary        0.756555  1.000000

# %%
df[['Exam_Score','Age']].corr()
# Out:
#             Exam_Score       Age
# Exam_Score    1.000000  0.351737
# Age           0.351737  1.000000
