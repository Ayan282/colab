# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayan282/colab/blob/main/statistika4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-353fb642-c9c6-43fa-b972-b2ce8e416bfd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-353fb642-c9c6-43fa-b972-b2ce8e416bfd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel("Data (2).xlsx")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 0            1    Male   20         IT        Bachelor      Baku     175
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 2            3    Male   21         IT        Bachelor      Baku     180
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 4            5    Male   24    Finance          Master      Baku     172
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 6            7    Male   22  Marketing        Bachelor      Baku     178
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 8            9    Male   23         IT          Master      Baku     185
# 9           10  Female   24  Marketing          Master     Ganja     170
# 10          11    Male   22    Finance        Bachelor      Baku     176
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# ...

# %%
from math import comb

# %%
A=df.loc[df["Exam_Score"]>80]
A["Exam_Score"].count()
# Out:
# np.int64(12)

# %%
df["Exam_Score"].count()
# Out:
# np.int64(20)

# %%
n=20
k=12
m=5
ehtimal=comb(k,m)/comb(n,m)
ehtimal
# Out:
# 0.05108359133126935

# %%
A=df.loc[df["Exam_Score"]>80]
p=A['Exam_Score'].count()/df['Exam_Score'].count()
n=10
k=7
binom=comb(n,k)*(p**k)*((1-p)**(n-k))
binom
# Out:
# np.float64(0.21499084799999998)

# %%
n=8
p=0.25
k=2
binom=comb(n,k)*(p**k)*((1-p)**(n-k))
binom
# Out:
# 0.31146240234375

# %%
f=df["Age"]
p_heryas=1/(25-20)
p_heryas
# Out:
# 0.2

# %%
cont_uniform=1/(185-160)
eht=(180-170)/(185-160)
eht
# Out:
# 0.4

# %%
uniform_dist=1/1600-600
ehtimal=(1200-800)/(1600-600)

# %%
orta=df["Exam_Score"].mean()

# %%
σ =df["Exam_Score"].std()

# %%
df["z_score"] = (df["Exam_Score"] - orta) / σ
df
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 0            1    Male   20         IT        Bachelor      Baku     175
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 2            3    Male   21         IT        Bachelor      Baku     180
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 4            5    Male   24    Finance          Master      Baku     172
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 6            7    Male   22  Marketing        Bachelor      Baku     178
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 8            9    Male   23         IT          Master      Baku     185
# 9           10  Female   24  Marketing          Master     Ganja     170
# 10          11    Male   22    Finance        Bachelor      Baku     176
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# ...
