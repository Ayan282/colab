# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayan282/colab/blob/main/statistika4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-104a8480-008a-4c52-b9f3-df2731815729" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-104a8480-008a-4c52-b9f3-df2731815729">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel("Data (2).xlsx")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 0            1    Male   20         IT        Bachelor      Baku     175
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 2            3    Male   21         IT        Bachelor      Baku     180
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 4            5    Male   24    Finance          Master      Baku     172
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 6            7    Male   22  Marketing        Bachelor      Baku     178
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 8            9    Male   23         IT          Master      Baku     185
# 9           10  Female   24  Marketing          Master     Ganja     170
# 10          11    Male   22    Finance        Bachelor      Baku     176
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# ...

# %%
from math import comb

# %%
A=df.loc[df["Exam_Score"]>80]
A["Exam_Score"].count()
# Out:
# np.int64(12)

# %%
df["Exam_Score"].count()
# Out:
# np.int64(20)

# %%
n=20
k=12
m=5
ehtimal=comb(k,m)/comb(n,m)
ehtimal
# Out:
# 0.05108359133126935

# %%
A=df.loc[df["Exam_Score"]>80]
p=A['Exam_Score'].count()/df['Exam_Score'].count()
n=10
k=7
binom=comb(n,k)*(p**k)*((1-p)**(n-k))
binom
# Out:
# np.float64(0.21499084799999998)

# %%
n=8
p=0.25
k=2
binom=comb(n,k)*(p**k)*((1-p)**(n-k))
binom
# Out:
# 0.31146240234375

# %%
f=df["Age"]
p_heryas=1/(25-20)
p_heryas
# Out:
# 0.2

# %%
cont_uniform=1/(185-160)
eht=(180-170)/(185-160)
eht
# Out:
# 0.4

# %%
uniform_dist=1/1600-600
ehtimal=(1200-800)/(1600-600)

# %%
orta=df["Exam_Score"].mean()

# %%
σ =df["Exam_Score"].std()

# %%
eht90=(90-orta)/σ
eht90
0.7764
# Out:
# np.float64(0.7678743362751246)

# %%
df["z_score"] = (df["Exam_Score"] - orta) / σ
df
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 0            1    Male   20         IT        Bachelor      Baku     175
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 2            3    Male   21         IT        Bachelor      Baku     180
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 4            5    Male   24    Finance          Master      Baku     172
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 6            7    Male   22  Marketing        Bachelor      Baku     178
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 8            9    Male   23         IT          Master      Baku     185
# 9           10  Female   24  Marketing          Master     Ganja     170
# 10          11    Male   22    Finance        Bachelor      Baku     176
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# ...

# %%
A=df.loc[df["z_score"]>1]
A["z_score"].count()
# Out:
# np.int64(3)

# %%
orta=df["Height"].mean()
orta
# Out:
# np.float64(171.7)

# %%
std=df["Height"].std()
std
# Out:
# 7.644055137645753

# %%
z_score170=(170-orta)/std
z_score170
eh1=1-0.5871
eh1
# Out:
# 0.41290000000000004

# %%
z_score180=(180-orta)/std
z_score180
eh2=0.8599-0.4120000000000004

# %%
z_score185=(185-orta)/std
z_score185
eh3=1-0.9582

# %%
orta=df["Salary"].mean()

# %%
std=df["Salary"].std()

# %%
z_score900=(900-orta)/std
z_score900
0.5199
# Out:
# np.float64(0.053462914136943984)

# %%
z_score1200=(1200-orta)/std
z_score1200
0.8830
# Out:
# np.float64(1.1990967885000292)

# %%
ehtimal=0.8830-0.5199
ehtimal
# Out:
# 0.3631

# %%
orta=df["Exam_Score"].mean()
orta
# Out:
# np.float64(82.75)

# %%
std=df['Exam_Score'].std()
std
# Out:
# 9.441649053110652

# %%
z_score=1.28

# %%
x=orta+std*z_score
x
# Out:
# np.float64(94.83531078798164)

# %% [markdown]
# texminen 94.8 baldan cox olan ballar yuxari 10%lik olur

# %%
import numpy as np

# %%
mean_score=70
std_score=5

# %%
sim_data=np.random.normal(loc=mean_score, scale=std_score, size=1000)

# %%
import seaborn as sns

# %%
sns.histplot(x="Exam_Score",data=df)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Count'>

# %%
sns.histplot(x=sim_data)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(x="Exam_Score",y="Salary",data=df)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Salary'>

# %%
sns.scatterplot(x="Exam_Score",y="Salary",data=df)
# Out:
# <Axes: xlabel='Exam_Score', ylabel='Salary'>

# %%
corr=df[['Exam_Score','Salary']].corr()
corr
# Out:
#             Exam_Score    Salary
# Exam_Score    1.000000  0.756555
# Salary        0.756555  1.000000

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Department', 'Education_Level',
#        'Region', 'Height', 'Weight', 'Exam_Score', 'Salary',
#        'Product_Category', 'Sales'],
#       dtype='object')

# %%
cols=["Student_ID", 'Age', 'Height', 'Weight', 'Exam_Score', 'Salary', 'Sales']
corr=df[cols].corr()
sns.heatmap(corr, annot=True, linewidths=0.5)
# Out:
# <Axes: >
