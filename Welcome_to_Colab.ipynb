# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayan282/colab/blob/main/Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Sample sales data
sales_data = pd.DataFrame({
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct"],
    "Product_A": [250, 300, 400, 350, 500, 450, 480, 470, 510, 550],
    "Product_B": [200, 220, 330, 300, 360, 390, 400, 420, 450, 480],
    "Product_C": [150, 180, 210, 200, 230, 250, 260, 280, 300, 320]
})

# Sample employee data
employee_data = pd.DataFrame({
    "EmployeeID": np.arange(1, 16),
    "Name": [f"Emp{i}" for i in range(1, 16)],
    "Department": np.random.choice(["HR", "Sales", "IT", "Finance"], size=15),
    "Salary": np.random.randint(40000, 120000, size=15),
    "ProjectsCompleted": np.random.randint(0, 20, size=15),
    "ExperienceYears": np.random.randint(1, 15, size=15)
})

# %%
sd=pd.DataFrame(sales_data)

# %%
ed=pd.DataFrame(employee_data)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(sd["Product_A"],sd["Month"])
plt.xlabel("Product_A")
plt.ylabel("Month")
# Out:
# Text(0, 0.5, 'Month')

# %%
plt.plot(sd["Product_A"],sd["Month"])
plt.plot(sd["Product_B"],sd["Month"])
plt.plot(sd["Product_C"],sd["Month"])
plt.ylabel("Month")
# Out:
# Text(0, 0.5, 'Month')

# %%
from matplotlib import legend
plt.scatter(ed["ExperienceYears"],ed["Salary"],color="red")
plt.xlabel("ExperienceYears")
plt.ylabel("Salary")
plt.title("ExperienceYears vs Salary")
plt.show()

# %%
plt.bar(ed["Name"],ed["ProjectsCompleted"])
plt.xticks(rotation=90)
plt.xlabel("Employee Name")
plt.ylabel("Projects Completed")
plt.title("Count of projects completed each name")
plt.legend()
plt.grid()
plt.show()
# Out:
# /tmp/ipython-input-2619380068.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.barh(ed["Department"],ed.groupby("Department")["Salary"].transform('mean'))
plt.show()

# %%
plt.hist(ed["Salary"],edgecolor='black')
# Out:
# (array([2., 3., 1., 2., 2., 0., 2., 0., 1., 2.]),
#  array([ 40186. ,  48037.7,  55889.4,  63741.1,  71592.8,  79444.5,
#          87296.2,  95147.9, 102999.6, 110851.3, 118703. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(ed["Salary"],ed["ProjectsCompleted"],color="red")
plt.scatter(a["Salary"],a["ProjectsCompleted"],color="blue")

# %%
a=ed.sort_values(by="ProjectsCompleted",ascending=False).head(3)
a
# Out:
#     EmployeeID   Name Department  Salary  ProjectsCompleted  ExperienceYears
# 13          14  Emp14         IT   42404                 19               14
# 8            9   Emp9      Sales   87770                 15               10
# 9           10  Emp10    Finance   74162                 15               10

# %%
sd["Umumi satis"]=sd["Product_A"]+sd["Product_B"]+sd["Product_C"]
sd
# Out:
#   Month  Product_A  Product_B  Product_C  Umumi satis
# 0   Jan        250        200        150          600
# 1   Feb        300        220        180          700
# 2   Mar        400        330        210          940
# 3   Apr        350        300        200          850
# 4   May        500        360        230         1090
# 5   Jun        450        390        250         1090
# 6   Jul        480        400        260         1140
# 7   Aug        470        420        280         1170
# 8   Sep        510        450        300         1260
# 9   Oct        550        480        320         1350

# %%
plt.plot(sd["Umumi satis"],sd["Month"])

# %%
ed.groupby("Department")["Name"].count()
# Out:
# Department
# Finance    5
# HR         3
# IT         3
# Sales      4
# Name: Name, dtype: int64

# %%
ed.groupby("Department")["Name"].count()
values=[5,3,3,4]
labels=["Finance","HR","IT","Sales"]
plt.pie(values,labels=labels)
# Out:
# ([<matplotlib.patches.Wedge at 0x7ddba8d5fd70>,
# ...
#  [Text(0.5499999722395388, 0.9526279601903919, 'Finance'),
#   Text(-1.0049000373055308, 0.44741023124571394, 'HR'),
#   Text(-0.7360435764729569, -0.8174593895313078, 'IT'),
#   Text(0.7360437908666487, -0.8174591964903528, 'Sales')])

# %%
sd["Umumi satis"]=sd["Product_A"]+sd["Product_B"]+sd["Product_C"]
sd["payA"]=sd["Product_A"]/sd["Umumi satis"]
sd["payB"]=sd["Product_B"]/sd["Umumi satis"]
sd["payC"]=sd["Product_C"]/sd["Umumi satis"]
sd
# Out:
#   Month  Product_A  Product_B  Product_C  Umumi satis      payA      payB  \
# 0   Jan        250        200        150          600  0.416667  0.333333
# 1   Feb        300        220        180          700  0.428571  0.314286
# 2   Mar        400        330        210          940  0.425532  0.351064
# 3   Apr        350        300        200          850  0.411765  0.352941
# 4   May        500        360        230         1090  0.458716  0.330275
# 5   Jun        450        390        250         1090  0.412844  0.357798
# 6   Jul        480        400        260         1140  0.421053  0.350877
# 7   Aug        470        420        280         1170  0.401709  0.358974
# 8   Sep        510        450        300         1260  0.404762  0.357143
# 9   Oct        550        480        320         1350  0.407407  0.355556
#
#        payC
# 0  0.250000
# 1  0.257143
# 2  0.223404
# 3  0.235294
# 4  0.211009
# 5  0.229358
# 6  0.228070
# 7  0.239316
# 8  0.238095
# 9  0.237037

# %%
plt.bar(sd["Month"],sd["payA"],label="Product_A")
plt.bar(sd["Month"],sd["payB"],bottom=sd["payA"],label="Product_B")
plt.bar(sd["Month"],sd["payC"],bottom=sd["payA"]+sd["payB"],label="Product_C")
plt.legend()
plt.show()

# %%
sd["cumsumA"]=sd["Product_A"].cumsum()
sd["cumsumB"]=sd["Product_B"].cumsum()
sd["cumsumC"]=sd["Product_C"].cumsum()
sd
# Out:
#   Month  Product_A  Product_B  Product_C  cumsumA  cumsumB  cumsumC
# 0   Jan        250        200        150      250      200      150
# 1   Feb        300        220        180      550      420      330
# 2   Mar        400        330        210      950      750      540
# 3   Apr        350        300        200     1300     1050      740
# 4   May        500        360        230     1800     1410      970
# 5   Jun        450        390        250     2250     1800     1220
# 6   Jul        480        400        260     2730     2200     1480
# 7   Aug        470        420        280     3200     2620     1760
# 8   Sep        510        450        300     3710     3070     2060
# 9   Oct        550        480        320     4260     3550     2380

# %%
plt.plot(sd["Month"],total)
plt.fill_between(sd["Month"],total,color="blue",alpha=0.5)

# %%
total=sd["cumsumA"]+sd["cumsumB"]+sd["cumsumC"]

# %%
sd["Umumi satis"]=sd["Product_A"]+sd["Product_B"]+sd["Product_C"]
sd
# Out:
#   Month  Product_A  Product_B  Product_C  Umumi satis
# 0   Jan        250        200        150          600
# 1   Feb        300        220        180          700
# 2   Mar        400        330        210          940
# 3   Apr        350        300        200          850
# 4   May        500        360        230         1090
# 5   Jun        450        390        250         1090
# 6   Jul        480        400        260         1140
# 7   Aug        470        420        280         1170
# 8   Sep        510        450        300         1260
# 9   Oct        550        480        320         1350

# %%
plt.stackplot(sd["Month"],sd["cumsumA"],sd["cumsumB"],sd["cumsumC"],labels=("A","B","C"))
plt.legend()
plt.show()

# %%
plt.bar(sd["Month"],sd["Product_A"],label="Product_A",color='red')
plt.bar(sd["Month"],sd["Product_B"],bottom=sd["Product_A"],label="Product_B",color='blue')
plt.bar(sd["Month"],sd["Product_C"],bottom=sd["Product_A"]+sd["Product_B"],label="Product_C",color='green')
plt.legend()
plt.show()

# %%
sd["Umumi satis"]=sd["Product_A"]+sd["Product_B"]+sd["Product_C"]
sd["payA"]=sd["Product_A"]/sd["Umumi satis"]*100
sd["payB"]=sd["Product_B"]/sd["Umumi satis"]*100
sd["payC"]=sd["Product_C"]/sd["Umumi satis"]*100
plt.bar(sd["Month"],sd["payA"],label="Product_A")
plt.bar(sd["Month"],sd["payB"],bottom=sd["payA"],label="Product_B")
plt.bar(sd["Month"],sd["payC"],bottom=sd["payA"]+sd["payB"],label="Product_C")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt


plt.subplot(2,2,1)
plt.plot(sd["Product_A"],sd["Month"])
plt.title("1")

plt.subplot(2,2,2)
plt.scatter(ed["Salary"],ed["ProjectsCompleted"],color="red")
plt.title("2")

plt.subplot(2,2,3)
plt.hist(ed["ExperienceYears"])
plt.title("3")

plt.subplot(2,2,4)
values=[5,3,3,4]
labels=["Finance","HR","IT","Sales"]
plt.pie(values,labels=labels)
plt.title("4")

plt.tight_layout()

plt.show()

# %%
plt.plot(sd["Umumi satis"],sd["Month"])
plt.scatter(sd["Product_C"],sd["Month"])

# %%
ed.boxplot(column="Salary",by="Department")
# Out:
# <Axes: title={'center': 'Salary'}, xlabel='Department'>

# %%
plt.boxplot(ed["Salary"])
plt.show()

# %%
ed.boxplot(column="Salary",by="Department")
# Out:
# <Axes: title={'center': 'Salary'}, xlabel='Department'>

# %%
plt.plot(sd["Product_B"],sd["Month"])
sd["Product_B"].max()
# Out:
# 480

# %%
max_sales=sd["Product_B"].max()
mindex=sd["Product_B"].tolist().index(max_sales)
plt.plot(sd["Month"],sd["Product_B"])
plt.annotate("Max salary",xy=(sd["Month"][mindex],max_sales),
xytext=(sd["Month"][mindex],max_sales))
# Out:
# Text(Oct, 480, 'Max salary')

# %%
mindex="Product_B".index(max_sales)
mindex
# Out:
# 4

# %%
import seaborn as sns
cols=["Salary","ProjectsCompleted","ExperienceYears"]
corr=ed[cols].corr
sns.heatmap(ed[cols].corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

months = ["Jan","Feb","Mar","Apr","May"]
sales = [100,150,220,180,260]

plt.plot(months, sales)

# maksimumu tapırıq
max_value = max(sales)
max_index = sales.index(max_value)

# annotasiya
plt.annotate("Highest Sales",
             xy=(months[max_index], max_value),
             xytext=(months[max_index], max_value+40),
             arrowprops=dict(arrowstyle="->"))

plt.show()
