# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayan282/colab/blob/main/statistika2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-bd8c2fad-cead-49b9-a915-a87055d7e22f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bd8c2fad-cead-49b9-a915-a87055d7e22f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel("Data (2).xlsx")

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 0            1    Male   20         IT        Bachelor      Baku     175
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 2            3    Male   21         IT        Bachelor      Baku     180
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 4            5    Male   24    Finance          Master      Baku     172
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 6            7    Male   22  Marketing        Bachelor      Baku     178
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 8            9    Male   23         IT          Master      Baku     185
# 9           10  Female   24  Marketing          Master     Ganja     170
# 10          11    Male   22    Finance        Bachelor      Baku     176
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# ...

# %%
df.loc[df["Gender"]=="Male"]
# Out:
#     Student_ID Gender  Age Department Education_Level Region  Height  Weight  \
# 0            1   Male   20         IT        Bachelor   Baku     175      70
# 2            3   Male   21         IT        Bachelor   Baku     180      80
# 4            5   Male   24    Finance          Master   Baku     172      75
# 6            7   Male   22  Marketing        Bachelor   Baku     178      82
# 8            9   Male   23         IT          Master   Baku     185      90
# 10          11   Male   22    Finance        Bachelor   Baku     176      77
# 12          13   Male   25  Marketing             PhD   Baku     182      85
# 14          15   Male   20         IT        Bachelor   Baku     174      72
# 16          17   Male   24    Finance          Master   Baku     177      79
# 18          19   Male   23  Marketing          Master   Baku     183      88
#
#     Exam_Score  Salary Product_Category  Sales
# 0           78     800      Electronics   1200
# ...

# %%
df.loc[df["Gender"]=="Female"]
# Out:
#     Student_ID  Gender  Age Department Education_Level    Region  Height  \
# 1            2  Female   22    Finance        Bachelor     Ganja     165
# 3            4  Female   23  Marketing          Master  Sumqayit     168
# 5            6  Female   20         IT        Bachelor     Ganja     160
# 7            8  Female   21    Finance        Bachelor  Sumqayit     162
# 9           10  Female   24  Marketing          Master     Ganja     170
# 11          12  Female   21         IT        Bachelor  Sumqayit     164
# 13          14  Female   23    Finance          Master     Ganja     166
# 15          16  Female   22  Marketing        Bachelor  Sumqayit     169
# 17          18  Female   21         IT        Bachelor     Ganja     161
# 19          20  Female   25    Finance             PhD      Baku     167
#
#     Weight  Exam_Score  Salary Product_Category  Sales
# 1       58          85     750         Clothing    900
# ...

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      10
# Female    10
# Name: count, dtype: int64

# %%
sns.barplot(x=["Male","Female"],y=[10,10],color='pink')
plt.title("Gender count")
plt.xlabel("Gender")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
a=df.groupby("Department")["Student_ID"].agg('count')
a
# Out:
# Department
# Finance      7
# IT           7
# Marketing    6
# Name: Student_ID, dtype: int64

# %%
faiz=(a/SUM)*100
faiz
# Out:
# Department
# Finance      35.0
# IT           35.0
# Marketing    30.0
# Name: Student_ID, dtype: float64

# %%
SUM=df.groupby("Department")["Student_ID"].agg('count').sum()
print(SUM)
# Out:
# 20

# %%
values=[35,35,30]
labels=["Finance","IT","Marketing"]
plt.pie(values,labels=labels,autopct='%1.1f%%',colors=['pink','skyblue','green'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f2c273251f0>,
# ...
#  [Text(0.4993895781431485, 0.9801071621215756, 'Finance'),
#   Text(-1.08645718962887, -0.17207781700073332, 'IT'),
#   Text(0.6465640158668551, -0.8899185206445168, 'Marketing')],
#  [Text(0.2723943153508082, 0.5346039066117684, '35.0%'),
#   Text(-0.5926130125248381, -0.09386062745494543, '35.0%'),
#   Text(0.3526712813819209, -0.4854101021697364, '30.0%')])
